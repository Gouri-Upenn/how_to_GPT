# %%
import openai
# %run secret_keys.ipynb
openai.api_key = OPENAI_KEY
completion = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "user", "content": "Compose a poem that explains the concept of recursion in programming."}
  ]
)
print(completion.choices[0].message.content)
message = completion.choices[0].message.content
# Out:
# In the world of code, there lies a powerful tool
# A concept so essential, it makes algorithms cool
# Recursion is its name, a loop within a loop
# A function calling itself, like a never-ending loop
#
# It's like a Russian doll, each one nested inside
# Executing again and again, with no place to hide
# It simplifies complex problems, breaking them down
# Into smaller pieces, like a puzzle to be found
#
# With each recursive call, the solution unfolds
# Building upon itself, like a story that's retold
# Until at last, the base case is reached
# And the recursion stops, the final piece breached
#
# So remember this lesson, when coding your way through
# Recursion is your friend, a powerful tool for you
# Embrace its endless loop, its elegance and grace
# And use it wisely, in every coding case.

# %%
import os
import openai
from pathlib import Path
from openai import OpenAI
from IPython.display import Audio

# %run secret_keys.ipynb
openai.api_key = OPENAI_KEY
cwd =Path.cwd()
speech_file_path = cwd/"speech.mp3"
response = openai.audio.speech.create(
  model="tts-1",
  voice="alloy",
  input= message
)
response.stream_to_file(speech_file_path)

# Embed and play the audio file in the notebook
Audio(str(speech_file_path))
# Out:
# C:\Users\gouri\AppData\Local\Temp\ipykernel_6892\973407278.py:16: DeprecationWarning: Due to a bug, this method doesn't actually stream the response content, `.with_streaming_response.method()` should be used instead
#   response.stream_to_file(speech_file_path)
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
